# %%
##############################################################
## 1. Libraries

import os
import cv2
import gym
from gym import spaces
import numpy as np
import random
from collections import deque
import time
import re
import sys

from keras.models import Model
from keras.layers import Dense, Embedding, Reshape, Flatten, Input, Conv2D, LeakyReLU
from keras.optimizers import Adam, RMSprop
from keras.utils import to_categorical

from matplotlib import pyplot as plt
from PIL import Image
import imageio

from keras import backend as K
import tensorflow as tf

##############################################################
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
##############################################################
## 2. Global Variables

DRIVE = True
ROOT = './'

if DRIVE:
    ROOT = 'drive/My Drive/PROYECTOS/RL/BreakOut_DQN/'
    from google.colab import drive
    drive.mount('/content/drive')

EPISODES = 100_000        # Episodes
LEARNING_RATE = 0.00025  # Agent learning rate 
ALPHA = 0.4             # Agent smoothing learning
GAMMA = 0.99           # Discount rate, the higher gamma the higher the focus on long term rewards
EPSILON = 1.0           # Exploration rate
KIND = 'small'          # Small/big DQN
MEMORY_SIZE = 53_000
WINDOW_FRAMES = 4

FRAME_WIDTH = 84
FRAME_HEIGHT = 84
STATE_LENGTH = 4

GIF_DURATION = 0.07
FRAMES_WINDOW = 14

path_input =  f'{ROOT}Training/'
path_output =  f'{ROOT}Training/'

##############################################################
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##############################################################
## 3. Functions

def sizeoFmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

def rgbToGray(img):
    # [0.2126, 0.7152, 0.0722] set the image in gray scale
    return np.dot(img, [0.2126, 0.7152, 0.0722])

def resizeImage(image, resized_shape = (84, 84), method = 'crop', crop_offset = 8):
    height, width = image.shape[0:2]
    r_height, r_width = resized_shape
    
    if method == 'crop':
        h = int(np.round(height * r_width / width, 0))
        resized = cv2.resize(image,
                            (r_width, h),
                            interpolation = cv2.INTER_LINEAR)
        crop_y_cutoff = h - crop_offset - r_height
        cropped = resized[crop_y_cutoff:crop_y_cutoff + r_height, :]
        return np.asarray(cropped, dtype = np.uint8)
    elif method == 'scale':
        return np.asarray(cv2.resize(image, (r_width, r_height), interpolation = cv2.INTER_LINEAR), dtype = np.uint8)
    else:
        raise ValueError('Method not implemented.')
        
        
def preprocessImage(img, resized_shape = (84, 84), crop_offset = 8, method = 'crop'):
    return rgbToGray(resizeImage(img, resized_shape = (84, 84), method = 'crop', crop_offset = 8))/255

def clipReward(reward):
    return np.sign(reward)

def saveEpisode(path_output, episode, list_images):
    
    try:
        os.mkdir(path_output)
    except:
        pass
    for i, img in enumerate(list_images):
        im = Image.fromarray(img)
        im.save(f'{path_output}epoch_{i}.png')
        
def sorted_aphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)    

def create_gif(path_input, path_output, episode, gif_name, duration):
    images = []
    
    try:
      files = [img for img in sorted_aphanumeric(os.listdir(path_input)) if img.endswith(".png")]
      
      for img in files:
          images.append(imageio.imread(path_input + img))

      imageio.mimsave(path_output + gif_name, images, duration = duration)
    except Except as e:
      pass
    
def createVideo(path_input, path_output, episode , video_name, frames_window = 14):
    images = [img for img in sorted_aphanumeric(os.listdir(path_input)) if img.endswith(".png")]
    frame = cv2.imread(os.path.join(path_input, images[0]))
    height, width, layers = frame.shape

    video = cv2.VideoWriter(path_output + video_name, 0, frames_window, (width, height))

    for image in images:
        video.write(cv2.imread(os.path.join(path_input, image)))

    cv2.destroyAllWindows()
    video.release()

def areSameImages(imgs1, imgs2):

    if imgs1.shape == imgs2.shape:
        if np.max(preprocessImage2(imgs1) - preprocessImage2(imgs2)) == 0:
            return True
        else:
            return False
    else:
        return False
    
##############################################################

# %%
##################################################
# 4. Classes

class DQNAgent:
    
    def __init__(self, action_size, lr, alpha, gamma, epsilon, kind, mem_size):
        self.action_size = action_size
        self.replay_memory = deque(maxlen = mem_size)
        self.window_frames = deque(maxlen = WINDOW_FRAMES)
        self.alpha = alpha
        self.learning_rate = lr
        self.gamma = gamma
        self.epsilon = epsilon
        self.output_dim = 24
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99985
        
        self.model = self.buildModel(kind)
        self.target_model = self.model
        
        
        self.update_target_model()
        
    def huberLoss(self, y_true, y_pred, clip_delta=1.0):
        error = y_true - y_pred
        cond  = K.abs(error) <= clip_delta

        squared_loss = 0.5 * K.square(error)
        quadratic_loss = 0.5 * K.square(clip_delta) + clip_delta * (K.abs(error) - clip_delta)

        return K.mean(tf.where(cond, squared_loss, quadratic_loss))
        
    def buildModel(self, kind = 'small'):
        input_frame = Input(shape = (FRAME_WIDTH, FRAME_HEIGHT, STATE_LENGTH))
        
        conv1 = Conv2D(32, 8, 4, subsample=(4, 4), activation='relu')(input_frame)
        conv2 = Conv2D(64, 4, 2, subsample=(2, 2), activation='relu')(conv1)
        conv3 = Conv2D(64, 3, 1, subsample=(1, 1), activation='relu')(conv2)
        
        x = Flatten()(conv3)
        x = Dense(512)(x)
        x = LeakyReLU()(x)
        
        q_value_prediction = Dense(self.action_size, activation = 'linear')(x)
        
        model = Model(inputs = input_frame, outputs = q_value_prediction)
        model.compile(loss = 'mse',
                      # loss = self.huberLoss, 
                      optimizer = RMSprop(lr=self.learning_rate))
        
        return model
    
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
    
    def act(self, state, ret_predictions = False):
        if (np.random.rand() <= self.epsilon):
            return random.randrange(self.action_size)
        else:
            predictions = self.model.predict(np.expand_dims(state.reshape(FRAME_WIDTH, FRAME_HEIGHT, STATE_LENGTH) , axis = 0))
        if ret_predictions == True:
          return predictions
        else:
          return np.argmax(predictions)
    
    def remember(self, state, action, reward, next_state, done):
        # self.addWindowFrame(state)
        if len(self.replay_memory) >= MEMORY_SIZE:
            self.replay_memory.popleft()
        self.replay_memory.append((state, action, reward, next_state, done))

    
    def replayMemory2(self, batch_size):
        x_states = []
        x_actions = []
        x_next_states = []
        y_rewards = []
        dones = []

        minibatch = random.sample(self.replay_memory, min(len(self.replay_memory), batch_size))
        
        for state, action, reward, next_state, done in minibatch:
            x_states.append(state)
            x_actions.append(action)
            x_next_states.append(next_state)
            y_rewards.append(reward)
            dones.append(done)
        
        x_states = np.array(x_states).reshape(batch_size, FRAME_WIDTH, FRAME_HEIGHT, STATE_LENGTH)
        x_next_states = np.array(x_next_states).reshape(batch_size, FRAME_WIDTH, FRAME_HEIGHT, STATE_LENGTH)
        
        q_s_action = self.model.predict(x_states)
        q_next_state_action = self.model.predict(x_next_states)
        q_target_next_state_action = self.target_model.predict(x_next_states)
        
        # q_s_values = np.zeros((batch_size, self.action_size))
        
        for i, elem in enumerate(q_s_action):
            #is_terminal
            if dones[i]: 
                q_s_action[i][x_actions[i]] = y_rewards[i]
                #q_s_values[i][x_actions[i]] = y_rewards[i]
            else:
                #next_best_action = np.argmax(q_next_state_action[i])
                q_s_action[i][x_actions[i]] = y_rewards[i] + (GAMMA * np.max(q_target_next_state_action[i]))
                #q_s_values[i][x_actions[i]] = y_rewards[i] + (GAMMA * q_target_next_state_action[i, next_best_action])

        hist = self.model.fit(x_states, q_s_action, batch_size = batch_size, verbose=0)
        loss = hist.history['loss'][0]

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
            
        return loss

###########################

class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env=None):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        super(EpisodicLifeEnv, self).__init__(env)
        self.lives = 0
        self.was_real_done = True
        self.was_real_reset = False

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert somtimes we stay in lives == 0 condtion for a few frames
            # so its important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset()
            self.was_real_reset = True
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
            self.was_real_reset = False
        self.lives = self.env.unwrapped.ale.lives()
        return obs
    
    
##################################################

# %%
##################################################
## 5. Workflow

# Done = All 5 lives are finished
# Reward = 1 if a brick is breaken 0 otherwise
# Actions: {0: No-op, 1:Fire(start game), 2: Right, 3: Left}

if __name__ == '__main__':
    
    # env = gym.make('Breakout-v0')   
    # env_wrp = EpisodicLifeEnv(env)
    env = EpisodicLifeEnv(gym.make('BreakoutDeterministic-v4'))
    action_size = 4
    
    agent = DQNAgent(action_size, LEARNING_RATE, ALPHA, GAMMA, EPSILON, KIND, MEMORY_SIZE)
    
    batch_size = 32
    loss = 1
    
    steps = 0
    max_epochs = 5_000
    
    last_20_ep_reward = deque(maxlen = 20)
    last_20_ep_loss = deque(maxlen = 20)
    
    for episode in range(EPISODES):

        done = False
        window_states = deque(maxlen = STATE_LENGTH)
        episode_suffix = f'Episode_{episode}/'
        tot_reward = 0
        frames = []
        first = True
        
        if first:
            state = env.reset()
            state, reward, done, _ = env.step(1)
            for i in range(STATE_LENGTH):
                window_states.append(preprocessImage(state))
            first = False
            empty_frame = state.copy()
        
        for epoch in range(max_epochs):
            steps += 1
            action = agent.act(np.asarray(window_states))
            next_state, reward, done, _ = env.step(action)
            reward = clipReward(reward)

            actual_window_states = np.asarray(window_states)
            window_states.append(preprocessImage(next_state))
            next_window_states = np.asarray(window_states)
            
            state = next_state

            tot_reward += reward

            if done:
                reward = -1
            
            agent.remember(actual_window_states, action, reward, next_window_states, done)

            if(episode % 500 == 0):
                frames.append(state)
            
            if steps % 10_000 == 0:
                print('Update target model')
                agent.update_target_model()
                
            if len(agent.replay_memory) > batch_size:
                loss = agent.replayMemory2(batch_size)

            if done and (episode % 500 == 0):
                print(f'Exporting episode: {episode} ...')
                saveEpisode(path_input + episode_suffix, episode, frames)
                create_gif(path_input + episode_suffix, path_output, episode, f'gif_episode_{episode}.gif', duration = GIF_DURATION)
                # createVideo(path_input + episode_suffix, path_output, episode, f'video_episode_{episode}.avi', frames_window = FRAMES_WINDOW)
                break
                
            if done:
                break

        last_20_ep_reward.append([tot_reward]) 
        last_20_ep_loss.append([loss])
        
        print(f'Episode: {episode}, Episode_Steps: {epoch}, Cum_Reward: {tot_reward},  Epsilon: {np.round(agent.epsilon, 4)}, Memory: {len(agent.replay_memory)}, Loss_last_20_ep: {np.round(np.mean(np.asarray(last_20_ep_loss)), 4)}, Reward_last_20_ep: {np.round(np.mean(np.asarray(last_20_ep_reward)), 2)}')

##################################################
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 4), activation="relu", strides=(4, 4))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 2), activation="relu", strides=(2, 2))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 1), activation="relu", strides=(1, 1))`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Exporting episode: 0 ...
# Episode: 0, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 1.0, Memory: 24, Loss_last_20_ep: 1.0, Reward_last_20_ep: 0.0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Episode: 1, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9976, Memory: 48, Loss_last_20_ep: 7.1348, Reward_last_20_ep: 0.0
# Episode: 2, Episode_Steps: 49, Cum_Reward: 1.0,  Epsilon: 0.9901, Memory: 98, Loss_last_20_ep: 5.8322, Reward_last_20_ep: 0.33
# Episode: 3, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9866, Memory: 122, Loss_last_20_ep: 4.8328, Reward_last_20_ep: 0.25
# Episode: 4, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.983, Memory: 146, Loss_last_20_ep: 4.7528, Reward_last_20_ep: 0.2
# Episode: 5, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9795, Memory: 170, Loss_last_20_ep: 4.5117, Reward_last_20_ep: 0.17
# Episode: 6, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.9763, Memory: 192, Loss_last_20_ep: 3.9897, Reward_last_20_ep: 0.14
# Episode: 7, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9728, Memory: 216, Loss_last_20_ep: 3.5004, Reward_last_20_ep: 0.12
# Episode: 8, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9693, Memory: 240, Loss_last_20_ep: 3.1433, Reward_last_20_ep: 0.11
# Episode: 9, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.9661, Memory: 262, Loss_last_20_ep: 2.8483, Reward_last_20_ep: 0.1
# Episode: 10, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9626, Memory: 286, Loss_last_20_ep: 2.6032, Reward_last_20_ep: 0.09
# Episode: 11, Episode_Steps: 71, Cum_Reward: 1.0,  Epsilon: 0.9523, Memory: 358, Loss_last_20_ep: 2.402, Reward_last_20_ep: 0.17
# Episode: 12, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9489, Memory: 382, Loss_last_20_ep: 2.2295, Reward_last_20_ep: 0.15
# Episode: 13, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9454, Memory: 406, Loss_last_20_ep: 2.0756, Reward_last_20_ep: 0.14
# Episode: 14, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.942, Memory: 430, Loss_last_20_ep: 1.9658, Reward_last_20_ep: 0.13
# Episode: 15, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9387, Memory: 454, Loss_last_20_ep: 1.843, Reward_last_20_ep: 0.12
# Episode: 16, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9353, Memory: 478, Loss_last_20_ep: 1.7413, Reward_last_20_ep: 0.12
# Episode: 17, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9319, Memory: 502, Loss_last_20_ep: 1.6447, Reward_last_20_ep: 0.11
# Episode: 18, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9286, Memory: 526, Loss_last_20_ep: 1.5695, Reward_last_20_ep: 0.11
# Episode: 19, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.9255, Memory: 548, Loss_last_20_ep: 1.5096, Reward_last_20_ep: 0.1
# Episode: 20, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9222, Memory: 572, Loss_last_20_ep: 1.4605, Reward_last_20_ep: 0.1
# Episode: 21, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.9191, Memory: 594, Loss_last_20_ep: 0.7977, Reward_last_20_ep: 0.1
# Episode: 22, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9158, Memory: 618, Loss_last_20_ep: 0.6453, Reward_last_20_ep: 0.05
# Episode: 23, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9126, Memory: 642, Loss_last_20_ep: 0.5563, Reward_last_20_ep: 0.05
# Episode: 24, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9093, Memory: 666, Loss_last_20_ep: 0.3363, Reward_last_20_ep: 0.05
# Episode: 25, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.906, Memory: 690, Loss_last_20_ep: 0.172, Reward_last_20_ep: 0.05
# Episode: 26, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.9028, Memory: 714, Loss_last_20_ep: 0.1379, Reward_last_20_ep: 0.05
# Episode: 27, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8995, Memory: 738, Loss_last_20_ep: 0.139, Reward_last_20_ep: 0.05
# Episode: 28, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8963, Memory: 762, Loss_last_20_ep: 0.1255, Reward_last_20_ep: 0.05
# Episode: 29, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.8893, Memory: 814, Loss_last_20_ep: 0.1314, Reward_last_20_ep: 0.1
# Episode: 30, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8861, Memory: 838, Loss_last_20_ep: 0.125, Reward_last_20_ep: 0.1
# Episode: 31, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8829, Memory: 862, Loss_last_20_ep: 0.1279, Reward_last_20_ep: 0.05
# Episode: 32, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8798, Memory: 886, Loss_last_20_ep: 0.1264, Reward_last_20_ep: 0.05
# Episode: 33, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8766, Memory: 910, Loss_last_20_ep: 0.1565, Reward_last_20_ep: 0.05
# Episode: 34, Episode_Steps: 49, Cum_Reward: 1.0,  Epsilon: 0.87, Memory: 960, Loss_last_20_ep: 0.1355, Reward_last_20_ep: 0.1
# Episode: 35, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8669, Memory: 984, Loss_last_20_ep: 0.1532, Reward_last_20_ep: 0.1
# Episode: 36, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8638, Memory: 1008, Loss_last_20_ep: 0.149, Reward_last_20_ep: 0.1
# Episode: 37, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8607, Memory: 1032, Loss_last_20_ep: 0.1571, Reward_last_20_ep: 0.1
# Episode: 38, Episode_Steps: 67, Cum_Reward: 1.0,  Epsilon: 0.852, Memory: 1100, Loss_last_20_ep: 0.1492, Reward_last_20_ep: 0.15
# Episode: 39, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8489, Memory: 1124, Loss_last_20_ep: 0.1314, Reward_last_20_ep: 0.15
# Episode: 40, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.8423, Memory: 1176, Loss_last_20_ep: 0.1311, Reward_last_20_ep: 0.2
# Episode: 41, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.8395, Memory: 1198, Loss_last_20_ep: 0.1314, Reward_last_20_ep: 0.2
# Episode: 42, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8365, Memory: 1222, Loss_last_20_ep: 0.1238, Reward_last_20_ep: 0.2
# Episode: 43, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.8338, Memory: 1244, Loss_last_20_ep: 0.3075, Reward_last_20_ep: 0.2
# Episode: 44, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8308, Memory: 1268, Loss_last_20_ep: 0.3267, Reward_last_20_ep: 0.2
# Episode: 45, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8278, Memory: 1292, Loss_last_20_ep: 0.3266, Reward_last_20_ep: 0.2
# Episode: 46, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8248, Memory: 1316, Loss_last_20_ep: 0.335, Reward_last_20_ep: 0.2
# Episode: 47, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8218, Memory: 1340, Loss_last_20_ep: 0.3326, Reward_last_20_ep: 0.2
# Episode: 48, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8189, Memory: 1364, Loss_last_20_ep: 0.3369, Reward_last_20_ep: 0.2
# Episode: 49, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.8162, Memory: 1386, Loss_last_20_ep: 0.3255, Reward_last_20_ep: 0.15
# Episode: 50, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8133, Memory: 1410, Loss_last_20_ep: 0.3747, Reward_last_20_ep: 0.15
# Episode: 51, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8103, Memory: 1434, Loss_last_20_ep: 0.3702, Reward_last_20_ep: 0.15
# Episode: 52, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.8077, Memory: 1456, Loss_last_20_ep: 0.37, Reward_last_20_ep: 0.15
# Episode: 53, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8048, Memory: 1480, Loss_last_20_ep: 0.344, Reward_last_20_ep: 0.15
# Episode: 54, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.8019, Memory: 1504, Loss_last_20_ep: 0.3664, Reward_last_20_ep: 0.1
# Episode: 55, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.799, Memory: 1528, Loss_last_20_ep: 0.3495, Reward_last_20_ep: 0.1
# Episode: 56, Episode_Steps: 96, Cum_Reward: 2.0,  Epsilon: 0.7874, Memory: 1625, Loss_last_20_ep: 0.36, Reward_last_20_ep: 0.2
# Episode: 57, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7846, Memory: 1649, Loss_last_20_ep: 0.3538, Reward_last_20_ep: 0.2
# Episode: 58, Episode_Steps: 98, Cum_Reward: 2.0,  Epsilon: 0.773, Memory: 1748, Loss_last_20_ep: 0.3696, Reward_last_20_ep: 0.25
# Episode: 59, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7703, Memory: 1772, Loss_last_20_ep: 0.3825, Reward_last_20_ep: 0.25
# Episode: 60, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7675, Memory: 1796, Loss_last_20_ep: 0.3849, Reward_last_20_ep: 0.2
# Episode: 61, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7647, Memory: 1820, Loss_last_20_ep: 0.3909, Reward_last_20_ep: 0.2
# Episode: 62, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.762, Memory: 1844, Loss_last_20_ep: 0.3935, Reward_last_20_ep: 0.2
# Episode: 63, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7593, Memory: 1868, Loss_last_20_ep: 0.2129, Reward_last_20_ep: 0.2
# Episode: 64, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.7568, Memory: 1890, Loss_last_20_ep: 0.1933, Reward_last_20_ep: 0.2
# Episode: 65, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.754, Memory: 1914, Loss_last_20_ep: 0.1929, Reward_last_20_ep: 0.2
# Episode: 66, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7513, Memory: 1938, Loss_last_20_ep: 0.1829, Reward_last_20_ep: 0.2
# Episode: 67, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.7455, Memory: 1990, Loss_last_20_ep: 0.1826, Reward_last_20_ep: 0.25
# Episode: 68, Episode_Steps: 118, Cum_Reward: 2.0,  Epsilon: 0.7323, Memory: 2109, Loss_last_20_ep: 0.1802, Reward_last_20_ep: 0.35
# Episode: 69, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7297, Memory: 2133, Loss_last_20_ep: 0.1763, Reward_last_20_ep: 0.35
# Episode: 70, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.727, Memory: 2157, Loss_last_20_ep: 0.1265, Reward_last_20_ep: 0.35
# Episode: 71, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.7246, Memory: 2179, Loss_last_20_ep: 0.1213, Reward_last_20_ep: 0.35
# Episode: 72, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.7223, Memory: 2201, Loss_last_20_ep: 0.1158, Reward_last_20_ep: 0.35
# Episode: 73, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7197, Memory: 2225, Loss_last_20_ep: 0.1089, Reward_last_20_ep: 0.35
# Episode: 74, Episode_Steps: 67, Cum_Reward: 1.0,  Epsilon: 0.7124, Memory: 2293, Loss_last_20_ep: 0.0863, Reward_last_20_ep: 0.4
# Episode: 75, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.7098, Memory: 2317, Loss_last_20_ep: 0.087, Reward_last_20_ep: 0.4
# Episode: 76, Episode_Steps: 117, Cum_Reward: 2.0,  Epsilon: 0.6973, Memory: 2435, Loss_last_20_ep: 0.0764, Reward_last_20_ep: 0.4
# Episode: 77, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.6919, Memory: 2487, Loss_last_20_ep: 0.0758, Reward_last_20_ep: 0.45
# Episode: 78, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6894, Memory: 2511, Loss_last_20_ep: 0.0574, Reward_last_20_ep: 0.35
# Episode: 79, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.687, Memory: 2535, Loss_last_20_ep: 0.0448, Reward_last_20_ep: 0.35
# Episode: 80, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6845, Memory: 2559, Loss_last_20_ep: 0.0436, Reward_last_20_ep: 0.35
# Episode: 81, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.682, Memory: 2583, Loss_last_20_ep: 0.0373, Reward_last_20_ep: 0.35
# Episode: 82, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6796, Memory: 2607, Loss_last_20_ep: 0.0334, Reward_last_20_ep: 0.35
# Episode: 83, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6771, Memory: 2631, Loss_last_20_ep: 0.0277, Reward_last_20_ep: 0.35
# Episode: 84, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6747, Memory: 2655, Loss_last_20_ep: 0.0266, Reward_last_20_ep: 0.35
# Episode: 85, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6723, Memory: 2679, Loss_last_20_ep: 0.0266, Reward_last_20_ep: 0.35
# Episode: 86, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6699, Memory: 2703, Loss_last_20_ep: 0.0197, Reward_last_20_ep: 0.35
# Episode: 87, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6675, Memory: 2727, Loss_last_20_ep: 0.0176, Reward_last_20_ep: 0.3
# Episode: 88, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6651, Memory: 2751, Loss_last_20_ep: 0.0154, Reward_last_20_ep: 0.2
# Episode: 89, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6627, Memory: 2775, Loss_last_20_ep: 0.0153, Reward_last_20_ep: 0.2
# Episode: 90, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6603, Memory: 2799, Loss_last_20_ep: 0.0147, Reward_last_20_ep: 0.2
# Episode: 91, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6579, Memory: 2823, Loss_last_20_ep: 0.0125, Reward_last_20_ep: 0.2
# Episode: 92, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.6528, Memory: 2875, Loss_last_20_ep: 0.0118, Reward_last_20_ep: 0.25
# Episode: 93, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.6507, Memory: 2897, Loss_last_20_ep: 0.0111, Reward_last_20_ep: 0.25
# Episode: 94, Episode_Steps: 164, Cum_Reward: 3.0,  Epsilon: 0.6347, Memory: 3062, Loss_last_20_ep: 0.0116, Reward_last_20_ep: 0.35
# Episode: 95, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6325, Memory: 3086, Loss_last_20_ep: 0.0114, Reward_last_20_ep: 0.35
# Episode: 96, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6302, Memory: 3110, Loss_last_20_ep: 0.0104, Reward_last_20_ep: 0.25
# Episode: 97, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6279, Memory: 3134, Loss_last_20_ep: 0.0091, Reward_last_20_ep: 0.2
# Episode: 98, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6257, Memory: 3158, Loss_last_20_ep: 0.0099, Reward_last_20_ep: 0.2
# Episode: 99, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6234, Memory: 3182, Loss_last_20_ep: 0.0096, Reward_last_20_ep: 0.2
# Episode: 100, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6212, Memory: 3206, Loss_last_20_ep: 0.0079, Reward_last_20_ep: 0.2
# Episode: 101, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6189, Memory: 3230, Loss_last_20_ep: 0.0082, Reward_last_20_ep: 0.2
# Episode: 102, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6167, Memory: 3254, Loss_last_20_ep: 0.0081, Reward_last_20_ep: 0.2
# Episode: 103, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.6119, Memory: 3306, Loss_last_20_ep: 0.0081, Reward_last_20_ep: 0.25
# Episode: 104, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.6071, Memory: 3359, Loss_last_20_ep: 0.0088, Reward_last_20_ep: 0.3
# Episode: 105, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.6049, Memory: 3383, Loss_last_20_ep: 0.0089, Reward_last_20_ep: 0.3
# Episode: 106, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.6029, Memory: 3405, Loss_last_20_ep: 0.0091, Reward_last_20_ep: 0.3
# Episode: 107, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.6009, Memory: 3427, Loss_last_20_ep: 0.0101, Reward_last_20_ep: 0.3
# Episode: 108, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5989, Memory: 3449, Loss_last_20_ep: 0.0421, Reward_last_20_ep: 0.3
# Episode: 109, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5968, Memory: 3473, Loss_last_20_ep: 0.0429, Reward_last_20_ep: 0.3
# Episode: 110, Episode_Steps: 72, Cum_Reward: 1.0,  Epsilon: 0.5903, Memory: 3546, Loss_last_20_ep: 0.0428, Reward_last_20_ep: 0.35
# Episode: 111, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5882, Memory: 3570, Loss_last_20_ep: 0.0434, Reward_last_20_ep: 0.35
# Episode: 112, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5861, Memory: 3594, Loss_last_20_ep: 0.0435, Reward_last_20_ep: 0.3
# Episode: 113, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5839, Memory: 3618, Loss_last_20_ep: 0.0461, Reward_last_20_ep: 0.3
# Episode: 114, Episode_Steps: 127, Cum_Reward: 3.0,  Epsilon: 0.5728, Memory: 3746, Loss_last_20_ep: 0.0457, Reward_last_20_ep: 0.3
# Episode: 115, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.5684, Memory: 3798, Loss_last_20_ep: 0.0521, Reward_last_20_ep: 0.35
# Episode: 116, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5665, Memory: 3820, Loss_last_20_ep: 0.0528, Reward_last_20_ep: 0.35
# Episode: 117, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.562, Memory: 3873, Loss_last_20_ep: 0.0537, Reward_last_20_ep: 0.4
# Episode: 118, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.56, Memory: 3897, Loss_last_20_ep: 0.053, Reward_last_20_ep: 0.4
# Episode: 119, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5582, Memory: 3919, Loss_last_20_ep: 0.0545, Reward_last_20_ep: 0.4
# Episode: 120, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5562, Memory: 3943, Loss_last_20_ep: 0.0544, Reward_last_20_ep: 0.4
# Episode: 121, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5542, Memory: 3967, Loss_last_20_ep: 0.054, Reward_last_20_ep: 0.4
# Episode: 122, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.5499, Memory: 4019, Loss_last_20_ep: 0.0541, Reward_last_20_ep: 0.45
# Episode: 123, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.548, Memory: 4041, Loss_last_20_ep: 0.0546, Reward_last_20_ep: 0.4
# Episode: 124, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5461, Memory: 4065, Loss_last_20_ep: 0.0542, Reward_last_20_ep: 0.35
# Episode: 125, Episode_Steps: 72, Cum_Reward: 1.0,  Epsilon: 0.5401, Memory: 4138, Loss_last_20_ep: 0.0544, Reward_last_20_ep: 0.4
# Episode: 126, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5383, Memory: 4160, Loss_last_20_ep: 0.0542, Reward_last_20_ep: 0.4
# Episode: 127, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5366, Memory: 4182, Loss_last_20_ep: 0.0531, Reward_last_20_ep: 0.4
# Episode: 128, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.5348, Memory: 4204, Loss_last_20_ep: 0.0255, Reward_last_20_ep: 0.4
# Episode: 129, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.5307, Memory: 4256, Loss_last_20_ep: 0.0255, Reward_last_20_ep: 0.45
# Episode: 130, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5287, Memory: 4280, Loss_last_20_ep: 0.0451, Reward_last_20_ep: 0.4
# Episode: 131, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.5246, Memory: 4332, Loss_last_20_ep: 0.0448, Reward_last_20_ep: 0.45
# Episode: 132, Episode_Steps: 84, Cum_Reward: 2.0,  Epsilon: 0.518, Memory: 4417, Loss_last_20_ep: 0.0448, Reward_last_20_ep: 0.55
# Episode: 133, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5161, Memory: 4441, Loss_last_20_ep: 0.0507, Reward_last_20_ep: 0.55
# Episode: 134, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.512, Memory: 4494, Loss_last_20_ep: 0.0509, Reward_last_20_ep: 0.45
# Episode: 135, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.5102, Memory: 4518, Loss_last_20_ep: 0.0437, Reward_last_20_ep: 0.4
# Episode: 136, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.5062, Memory: 4570, Loss_last_20_ep: 0.0435, Reward_last_20_ep: 0.45
# Episode: 137, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.5022, Memory: 4624, Loss_last_20_ep: 0.043, Reward_last_20_ep: 0.45
# Episode: 138, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.498, Memory: 4679, Loss_last_20_ep: 0.0429, Reward_last_20_ep: 0.5
# Episode: 139, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4962, Memory: 4703, Loss_last_20_ep: 0.0418, Reward_last_20_ep: 0.5
# Episode: 140, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4945, Memory: 4727, Loss_last_20_ep: 0.0424, Reward_last_20_ep: 0.5
# Episode: 141, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4927, Memory: 4751, Loss_last_20_ep: 0.0433, Reward_last_20_ep: 0.5
# Episode: 142, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4888, Memory: 4803, Loss_last_20_ep: 0.0433, Reward_last_20_ep: 0.5
# Episode: 143, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.4872, Memory: 4825, Loss_last_20_ep: 0.0429, Reward_last_20_ep: 0.5
# Episode: 144, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4855, Memory: 4849, Loss_last_20_ep: 0.0432, Reward_last_20_ep: 0.5
# Episode: 145, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4817, Memory: 4901, Loss_last_20_ep: 0.0434, Reward_last_20_ep: 0.5
# Episode: 146, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.48, Memory: 4925, Loss_last_20_ep: 0.0432, Reward_last_20_ep: 0.5
# Episode: 147, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.4761, Memory: 4979, Loss_last_20_ep: 0.0432, Reward_last_20_ep: 0.55
# Episode: 148, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.4722, Memory: 5034, Loss_last_20_ep: 0.0386, Reward_last_20_ep: 0.6
# Episode: 149, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.4682, Memory: 5090, Loss_last_20_ep: 0.0382, Reward_last_20_ep: 0.6
# Episode: 150, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4646, Memory: 5142, Loss_last_20_ep: 0.0189, Reward_last_20_ep: 0.65
# Episode: 151, Episode_Steps: 83, Cum_Reward: 2.0,  Epsilon: 0.4588, Memory: 5226, Loss_last_20_ep: 0.0184, Reward_last_20_ep: 0.7
# Episode: 152, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4571, Memory: 5250, Loss_last_20_ep: 0.0187, Reward_last_20_ep: 0.6
# Episode: 153, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4555, Memory: 5274, Loss_last_20_ep: 0.0103, Reward_last_20_ep: 0.6
# Episode: 154, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.454, Memory: 5296, Loss_last_20_ep: 0.0105, Reward_last_20_ep: 0.55
# Episode: 155, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4524, Memory: 5320, Loss_last_20_ep: 0.015, Reward_last_20_ep: 0.55
# Episode: 156, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4489, Memory: 5372, Loss_last_20_ep: 0.0169, Reward_last_20_ep: 0.55
# Episode: 157, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4472, Memory: 5396, Loss_last_20_ep: 0.0171, Reward_last_20_ep: 0.5
# Episode: 158, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.4458, Memory: 5418, Loss_last_20_ep: 0.0173, Reward_last_20_ep: 0.45
# Episode: 159, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.4422, Memory: 5471, Loss_last_20_ep: 0.017, Reward_last_20_ep: 0.5
# Episode: 160, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4388, Memory: 5523, Loss_last_20_ep: 0.0168, Reward_last_20_ep: 0.55
# Episode: 161, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.4353, Memory: 5577, Loss_last_20_ep: 0.0209, Reward_last_20_ep: 0.6
# Episode: 162, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.4337, Memory: 5601, Loss_last_20_ep: 0.0214, Reward_last_20_ep: 0.55
# Episode: 163, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.4301, Memory: 5656, Loss_last_20_ep: 0.0217, Reward_last_20_ep: 0.6
# Episode: 164, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.4265, Memory: 5712, Loss_last_20_ep: 0.0214, Reward_last_20_ep: 0.65
# Episode: 165, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4232, Memory: 5764, Loss_last_20_ep: 0.0223, Reward_last_20_ep: 0.65
# Episode: 166, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.4198, Memory: 5818, Loss_last_20_ep: 0.0252, Reward_last_20_ep: 0.7
# Episode: 167, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.4184, Memory: 5840, Loss_last_20_ep: 0.0261, Reward_last_20_ep: 0.65
# Episode: 168, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.415, Memory: 5895, Loss_last_20_ep: 0.0263, Reward_last_20_ep: 0.65
# Episode: 169, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.4117, Memory: 5948, Loss_last_20_ep: 0.026, Reward_last_20_ep: 0.65
# Episode: 170, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.4085, Memory: 6000, Loss_last_20_ep: 0.0284, Reward_last_20_ep: 0.65
# Episode: 171, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.4052, Memory: 6054, Loss_last_20_ep: 0.0285, Reward_last_20_ep: 0.6
# Episode: 172, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.4019, Memory: 6109, Loss_last_20_ep: 0.0288, Reward_last_20_ep: 0.65
# Episode: 173, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.3987, Memory: 6162, Loss_last_20_ep: 0.0326, Reward_last_20_ep: 0.7
# Episode: 174, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.3973, Memory: 6186, Loss_last_20_ep: 0.0321, Reward_last_20_ep: 0.7
# Episode: 175, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.3958, Memory: 6210, Loss_last_20_ep: 0.0273, Reward_last_20_ep: 0.7
# Episode: 176, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.3945, Memory: 6232, Loss_last_20_ep: 0.0251, Reward_last_20_ep: 0.65
# Episode: 177, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3915, Memory: 6284, Loss_last_20_ep: 0.0251, Reward_last_20_ep: 0.7
# Episode: 178, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3883, Memory: 6338, Loss_last_20_ep: 0.025, Reward_last_20_ep: 0.75
# Episode: 179, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3851, Memory: 6393, Loss_last_20_ep: 0.0244, Reward_last_20_ep: 0.75
# Episode: 180, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3821, Memory: 6445, Loss_last_20_ep: 0.0265, Reward_last_20_ep: 0.75
# Episode: 181, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.3807, Memory: 6469, Loss_last_20_ep: 0.0219, Reward_last_20_ep: 0.7
# Episode: 182, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.3794, Memory: 6493, Loss_last_20_ep: 0.022, Reward_last_20_ep: 0.7
# Episode: 183, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3763, Memory: 6547, Loss_last_20_ep: 0.023, Reward_last_20_ep: 0.7
# Episode: 184, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3732, Memory: 6602, Loss_last_20_ep: 0.0243, Reward_last_20_ep: 0.7
# Episode: 185, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3703, Memory: 6654, Loss_last_20_ep: 0.023, Reward_last_20_ep: 0.7
# Episode: 186, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.369, Memory: 6678, Loss_last_20_ep: 0.0207, Reward_last_20_ep: 0.65
# Episode: 187, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.366, Memory: 6732, Loss_last_20_ep: 0.0203, Reward_last_20_ep: 0.7
# Episode: 188, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.3631, Memory: 6785, Loss_last_20_ep: 0.0274, Reward_last_20_ep: 0.7
# Episode: 189, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3601, Memory: 6840, Loss_last_20_ep: 0.0276, Reward_last_20_ep: 0.7
# Episode: 190, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3573, Memory: 6892, Loss_last_20_ep: 0.0257, Reward_last_20_ep: 0.7
# Episode: 191, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3545, Memory: 6946, Loss_last_20_ep: 0.0268, Reward_last_20_ep: 0.7
# Episode: 192, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.3533, Memory: 6968, Loss_last_20_ep: 0.0273, Reward_last_20_ep: 0.65
# Episode: 193, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3504, Memory: 7023, Loss_last_20_ep: 0.0278, Reward_last_20_ep: 0.65
# Episode: 194, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.3492, Memory: 7045, Loss_last_20_ep: 0.028, Reward_last_20_ep: 0.65
# Episode: 195, Episode_Steps: 184, Cum_Reward: 4.0,  Epsilon: 0.3397, Memory: 7230, Loss_last_20_ep: 0.0329, Reward_last_20_ep: 0.85
# Episode: 196, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.337, Memory: 7282, Loss_last_20_ep: 0.0332, Reward_last_20_ep: 0.9
# Episode: 197, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3343, Memory: 7336, Loss_last_20_ep: 0.033, Reward_last_20_ep: 0.9
# Episode: 198, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3316, Memory: 7391, Loss_last_20_ep: 0.0331, Reward_last_20_ep: 0.9
# Episode: 199, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.3305, Memory: 7413, Loss_last_20_ep: 0.0337, Reward_last_20_ep: 0.85
# Episode: 200, Episode_Steps: 184, Cum_Reward: 4.0,  Epsilon: 0.3214, Memory: 7598, Loss_last_20_ep: 0.0317, Reward_last_20_ep: 1.0
# Episode: 201, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3189, Memory: 7650, Loss_last_20_ep: 0.0337, Reward_last_20_ep: 1.05
# Episode: 202, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3164, Memory: 7704, Loss_last_20_ep: 0.0337, Reward_last_20_ep: 1.1
# Episode: 203, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3138, Memory: 7759, Loss_last_20_ep: 0.0332, Reward_last_20_ep: 1.1
# Episode: 204, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.3111, Memory: 7815, Loss_last_20_ep: 0.0354, Reward_last_20_ep: 1.1
# Episode: 205, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.3087, Memory: 7867, Loss_last_20_ep: 0.0362, Reward_last_20_ep: 1.1
# Episode: 206, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.3076, Memory: 7891, Loss_last_20_ep: 0.0363, Reward_last_20_ep: 1.1
# Episode: 207, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.3051, Memory: 7945, Loss_last_20_ep: 0.0367, Reward_last_20_ep: 1.1
# Episode: 208, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.3026, Memory: 8000, Loss_last_20_ep: 0.0413, Reward_last_20_ep: 1.1
# Episode: 209, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.3002, Memory: 8053, Loss_last_20_ep: 0.0415, Reward_last_20_ep: 1.1
# Episode: 210, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2979, Memory: 8105, Loss_last_20_ep: 0.0415, Reward_last_20_ep: 1.1
# Episode: 211, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2955, Memory: 8159, Loss_last_20_ep: 0.0408, Reward_last_20_ep: 1.1
# Episode: 212, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2945, Memory: 8181, Loss_last_20_ep: 0.0412, Reward_last_20_ep: 1.1
# Episode: 213, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2921, Memory: 8236, Loss_last_20_ep: 0.0383, Reward_last_20_ep: 1.1
# Episode: 214, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.2896, Memory: 8292, Loss_last_20_ep: 0.0403, Reward_last_20_ep: 1.15
# Episode: 215, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.2853, Memory: 8393, Loss_last_20_ep: 0.0368, Reward_last_20_ep: 1.05
# Episode: 216, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.283, Memory: 8447, Loss_last_20_ep: 0.0373, Reward_last_20_ep: 1.05
# Episode: 217, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2807, Memory: 8502, Loss_last_20_ep: 0.0394, Reward_last_20_ep: 1.05
# Episode: 218, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.2783, Memory: 8558, Loss_last_20_ep: 0.0409, Reward_last_20_ep: 1.05
# Episode: 219, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.2764, Memory: 8603, Loss_last_20_ep: 0.0415, Reward_last_20_ep: 1.1
# Episode: 220, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2755, Memory: 8627, Loss_last_20_ep: 0.044, Reward_last_20_ep: 0.9
# Episode: 221, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2733, Memory: 8679, Loss_last_20_ep: 0.0417, Reward_last_20_ep: 0.9
# Episode: 222, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2711, Memory: 8733, Loss_last_20_ep: 0.0418, Reward_last_20_ep: 0.9
# Episode: 223, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.269, Memory: 8786, Loss_last_20_ep: 0.0416, Reward_last_20_ep: 0.9
# Episode: 224, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2667, Memory: 8841, Loss_last_20_ep: 0.0396, Reward_last_20_ep: 0.9
# Episode: 225, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2647, Memory: 8893, Loss_last_20_ep: 0.0393, Reward_last_20_ep: 0.9
# Episode: 226, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2625, Memory: 8947, Loss_last_20_ep: 0.04, Reward_last_20_ep: 0.95
# Episode: 227, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.2586, Memory: 9048, Loss_last_20_ep: 0.0411, Reward_last_20_ep: 1.0
# Episode: 228, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2577, Memory: 9070, Loss_last_20_ep: 0.0317, Reward_last_20_ep: 0.95
# Episode: 229, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2556, Memory: 9125, Loss_last_20_ep: 0.032, Reward_last_20_ep: 0.95
# Episode: 230, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2536, Memory: 9177, Loss_last_20_ep: 0.1068, Reward_last_20_ep: 0.95
# Episode: 231, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2527, Memory: 9201, Loss_last_20_ep: 0.1066, Reward_last_20_ep: 0.9
# Episode: 232, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2507, Memory: 9255, Loss_last_20_ep: 0.1056, Reward_last_20_ep: 0.95
# Episode: 233, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2486, Memory: 9310, Loss_last_20_ep: 0.1043, Reward_last_20_ep: 0.95
# Episode: 234, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.2465, Memory: 9366, Loss_last_20_ep: 0.1024, Reward_last_20_ep: 0.95
# Episode: 235, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2446, Memory: 9418, Loss_last_20_ep: 0.1015, Reward_last_20_ep: 0.9
# Episode: 236, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2427, Memory: 9472, Loss_last_20_ep: 0.1018, Reward_last_20_ep: 0.9
# Episode: 237, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2407, Memory: 9527, Loss_last_20_ep: 0.1001, Reward_last_20_ep: 0.9
# Episode: 238, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.2386, Memory: 9583, Loss_last_20_ep: 0.0989, Reward_last_20_ep: 0.9
# Episode: 239, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.237, Memory: 9628, Loss_last_20_ep: 0.0979, Reward_last_20_ep: 0.9
# Episode: 240, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2352, Memory: 9680, Loss_last_20_ep: 0.0956, Reward_last_20_ep: 0.95
# Episode: 241, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2344, Memory: 9702, Loss_last_20_ep: 0.0954, Reward_last_20_ep: 0.9
# Episode: 242, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2325, Memory: 9756, Loss_last_20_ep: 0.0962, Reward_last_20_ep: 0.9
# Episode: 243, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2306, Memory: 9811, Loss_last_20_ep: 0.0976, Reward_last_20_ep: 0.9
# Episode: 244, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2299, Memory: 9833, Loss_last_20_ep: 0.0965, Reward_last_20_ep: 0.85
# Episode: 245, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2281, Memory: 9885, Loss_last_20_ep: 0.0959, Reward_last_20_ep: 0.85
# Episode: 246, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2273, Memory: 9907, Loss_last_20_ep: 0.0953, Reward_last_20_ep: 0.8
# Episode: 247, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2265, Memory: 9931, Loss_last_20_ep: 0.0945, Reward_last_20_ep: 0.7
# Episode: 248, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2247, Memory: 9985, Loss_last_20_ep: 0.0928, Reward_last_20_ep: 0.75
# Update target model
# Episode: 249, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2228, Memory: 10040, Loss_last_20_ep: 0.0942, Reward_last_20_ep: 0.75
# Episode: 250, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2211, Memory: 10092, Loss_last_20_ep: 0.0197, Reward_last_20_ep: 0.75
# Episode: 251, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.2193, Memory: 10146, Loss_last_20_ep: 0.0196, Reward_last_20_ep: 0.8
# Episode: 252, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.2175, Memory: 10201, Loss_last_20_ep: 0.0197, Reward_last_20_ep: 0.8
# Episode: 253, Episode_Steps: 150, Cum_Reward: 3.0,  Epsilon: 0.2126, Memory: 10352, Loss_last_20_ep: 0.0248, Reward_last_20_ep: 0.9
# Episode: 254, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.2119, Memory: 10374, Loss_last_20_ep: 0.0259, Reward_last_20_ep: 0.85
# Episode: 255, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2103, Memory: 10426, Loss_last_20_ep: 0.0255, Reward_last_20_ep: 0.85
# Episode: 256, Episode_Steps: 84, Cum_Reward: 2.0,  Epsilon: 0.2076, Memory: 10511, Loss_last_20_ep: 0.0241, Reward_last_20_ep: 0.9
# Episode: 257, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2069, Memory: 10535, Loss_last_20_ep: 0.0239, Reward_last_20_ep: 0.85
# Episode: 258, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2061, Memory: 10559, Loss_last_20_ep: 0.0237, Reward_last_20_ep: 0.8
# Episode: 259, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.2054, Memory: 10583, Loss_last_20_ep: 0.0238, Reward_last_20_ep: 0.75
# Episode: 260, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.2038, Memory: 10635, Loss_last_20_ep: 0.0237, Reward_last_20_ep: 0.75
# Episode: 261, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.2022, Memory: 10688, Loss_last_20_ep: 0.0241, Reward_last_20_ep: 0.8
# Episode: 262, Episode_Steps: 50, Cum_Reward: 1.0,  Epsilon: 0.2007, Memory: 10739, Loss_last_20_ep: 0.0252, Reward_last_20_ep: 0.8
# Episode: 263, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.199, Memory: 10793, Loss_last_20_ep: 0.0234, Reward_last_20_ep: 0.8
# Episode: 264, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1974, Memory: 10847, Loss_last_20_ep: 0.023, Reward_last_20_ep: 0.85
# Episode: 265, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1959, Memory: 10899, Loss_last_20_ep: 0.0229, Reward_last_20_ep: 0.85
# Episode: 266, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1943, Memory: 10953, Loss_last_20_ep: 0.0225, Reward_last_20_ep: 0.9
# Episode: 267, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1927, Memory: 11008, Loss_last_20_ep: 0.0217, Reward_last_20_ep: 0.95
# Episode: 268, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1911, Memory: 11064, Loss_last_20_ep: 0.0306, Reward_last_20_ep: 0.95
# Episode: 269, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.1898, Memory: 11109, Loss_last_20_ep: 0.0288, Reward_last_20_ep: 0.95
# Episode: 270, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1883, Memory: 11161, Loss_last_20_ep: 0.028, Reward_last_20_ep: 0.95
# Episode: 271, Episode_Steps: 84, Cum_Reward: 2.0,  Epsilon: 0.186, Memory: 11246, Loss_last_20_ep: 0.028, Reward_last_20_ep: 1.0
# Episode: 272, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1853, Memory: 11270, Loss_last_20_ep: 0.0279, Reward_last_20_ep: 0.95
# Episode: 273, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1838, Memory: 11325, Loss_last_20_ep: 0.023, Reward_last_20_ep: 0.85
# Episode: 274, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1822, Memory: 11381, Loss_last_20_ep: 0.0257, Reward_last_20_ep: 0.9
# Episode: 275, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1808, Memory: 11433, Loss_last_20_ep: 0.0261, Reward_last_20_ep: 0.9
# Episode: 276, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1794, Memory: 11487, Loss_last_20_ep: 0.0263, Reward_last_20_ep: 0.85
# Episode: 277, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1788, Memory: 11509, Loss_last_20_ep: 0.0266, Reward_last_20_ep: 0.85
# Episode: 278, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1773, Memory: 11564, Loss_last_20_ep: 0.0265, Reward_last_20_ep: 0.9
# Episode: 279, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1758, Memory: 11620, Loss_last_20_ep: 0.0262, Reward_last_20_ep: 0.95
# Episode: 280, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1744, Memory: 11672, Loss_last_20_ep: 0.0264, Reward_last_20_ep: 0.95
# Episode: 281, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.173, Memory: 11726, Loss_last_20_ep: 0.0263, Reward_last_20_ep: 0.95
# Episode: 282, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1716, Memory: 11781, Loss_last_20_ep: 0.0251, Reward_last_20_ep: 0.95
# Episode: 283, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1702, Memory: 11837, Loss_last_20_ep: 0.0264, Reward_last_20_ep: 0.95
# Episode: 284, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.169, Memory: 11882, Loss_last_20_ep: 0.027, Reward_last_20_ep: 0.95
# Episode: 285, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1677, Memory: 11934, Loss_last_20_ep: 0.0366, Reward_last_20_ep: 0.95
# Episode: 286, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1664, Memory: 11988, Loss_last_20_ep: 0.0364, Reward_last_20_ep: 0.95
# Episode: 287, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.165, Memory: 12043, Loss_last_20_ep: 0.0415, Reward_last_20_ep: 0.95
# Episode: 288, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1636, Memory: 12099, Loss_last_20_ep: 0.032, Reward_last_20_ep: 0.95
# Episode: 289, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.1625, Memory: 12144, Loss_last_20_ep: 0.0323, Reward_last_20_ep: 0.95
# Episode: 290, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1613, Memory: 12196, Loss_last_20_ep: 0.0325, Reward_last_20_ep: 0.95
# Episode: 291, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.16, Memory: 12250, Loss_last_20_ep: 0.0324, Reward_last_20_ep: 0.9
# Episode: 292, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1586, Memory: 12305, Loss_last_20_ep: 0.0333, Reward_last_20_ep: 0.95
# Episode: 293, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1581, Memory: 12329, Loss_last_20_ep: 0.0333, Reward_last_20_ep: 0.9
# Episode: 294, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1575, Memory: 12353, Loss_last_20_ep: 0.0303, Reward_last_20_ep: 0.85
# Episode: 295, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1563, Memory: 12405, Loss_last_20_ep: 0.0303, Reward_last_20_ep: 0.85
# Episode: 296, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.155, Memory: 12459, Loss_last_20_ep: 0.0307, Reward_last_20_ep: 0.85
# Episode: 297, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1545, Memory: 12483, Loss_last_20_ep: 0.0309, Reward_last_20_ep: 0.85
# Episode: 298, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1532, Memory: 12538, Loss_last_20_ep: 0.0312, Reward_last_20_ep: 0.85
# Episode: 299, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1527, Memory: 12560, Loss_last_20_ep: 0.0313, Reward_last_20_ep: 0.8
# Episode: 300, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1515, Memory: 12612, Loss_last_20_ep: 0.0317, Reward_last_20_ep: 0.8
# Episode: 301, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1503, Memory: 12666, Loss_last_20_ep: 0.0318, Reward_last_20_ep: 0.8
# Episode: 302, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.149, Memory: 12721, Loss_last_20_ep: 0.0305, Reward_last_20_ep: 0.8
# Episode: 303, Episode_Steps: 50, Cum_Reward: 1.0,  Epsilon: 0.1479, Memory: 12772, Loss_last_20_ep: 0.0292, Reward_last_20_ep: 0.8
# Episode: 304, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1467, Memory: 12828, Loss_last_20_ep: 0.0286, Reward_last_20_ep: 0.8
# Episode: 305, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1455, Memory: 12880, Loss_last_20_ep: 0.0201, Reward_last_20_ep: 0.8
# Episode: 306, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1444, Memory: 12934, Loss_last_20_ep: 0.02, Reward_last_20_ep: 0.8
# Episode: 307, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1432, Memory: 12989, Loss_last_20_ep: 0.0151, Reward_last_20_ep: 0.8
# Episode: 308, Episode_Steps: 71, Cum_Reward: 1.0,  Epsilon: 0.1416, Memory: 13061, Loss_last_20_ep: 0.015, Reward_last_20_ep: 0.8
# Episode: 309, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1412, Memory: 13083, Loss_last_20_ep: 0.0146, Reward_last_20_ep: 0.75
# Episode: 310, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1401, Memory: 13135, Loss_last_20_ep: 0.0149, Reward_last_20_ep: 0.75
# Episode: 311, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1389, Memory: 13189, Loss_last_20_ep: 0.0148, Reward_last_20_ep: 0.75
# Episode: 312, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1384, Memory: 13213, Loss_last_20_ep: 0.0138, Reward_last_20_ep: 0.7
# Episode: 313, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.138, Memory: 13235, Loss_last_20_ep: 0.0139, Reward_last_20_ep: 0.7
# Episode: 314, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1375, Memory: 13257, Loss_last_20_ep: 0.0137, Reward_last_20_ep: 0.7
# Episode: 315, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1365, Memory: 13309, Loss_last_20_ep: 0.0137, Reward_last_20_ep: 0.7
# Episode: 316, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.136, Memory: 13331, Loss_last_20_ep: 0.0158, Reward_last_20_ep: 0.65
# Episode: 317, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1349, Memory: 13385, Loss_last_20_ep: 0.0151, Reward_last_20_ep: 0.7
# Episode: 318, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1338, Memory: 13440, Loss_last_20_ep: 0.0148, Reward_last_20_ep: 0.7
# Episode: 319, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1334, Memory: 13462, Loss_last_20_ep: 0.0156, Reward_last_20_ep: 0.7
# Episode: 320, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1323, Memory: 13514, Loss_last_20_ep: 0.0153, Reward_last_20_ep: 0.7
# Episode: 321, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1313, Memory: 13568, Loss_last_20_ep: 0.0167, Reward_last_20_ep: 0.7
# Episode: 322, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1302, Memory: 13623, Loss_last_20_ep: 0.0313, Reward_last_20_ep: 0.7
# Episode: 323, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1291, Memory: 13679, Loss_last_20_ep: 0.0313, Reward_last_20_ep: 0.7
# Episode: 324, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1287, Memory: 13701, Loss_last_20_ep: 0.0312, Reward_last_20_ep: 0.65
# Episode: 325, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1277, Memory: 13753, Loss_last_20_ep: 0.0306, Reward_last_20_ep: 0.65
# Episode: 326, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1266, Memory: 13807, Loss_last_20_ep: 0.0307, Reward_last_20_ep: 0.65
# Episode: 327, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.1247, Memory: 13908, Loss_last_20_ep: 0.0337, Reward_last_20_ep: 0.7
# Episode: 328, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1243, Memory: 13930, Loss_last_20_ep: 0.0342, Reward_last_20_ep: 0.65
# Episode: 329, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1239, Memory: 13954, Loss_last_20_ep: 0.0342, Reward_last_20_ep: 0.65
# Episode: 330, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1229, Memory: 14006, Loss_last_20_ep: 0.0349, Reward_last_20_ep: 0.65
# Episode: 331, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1219, Memory: 14060, Loss_last_20_ep: 0.035, Reward_last_20_ep: 0.65
# Episode: 332, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1209, Memory: 14115, Loss_last_20_ep: 0.0363, Reward_last_20_ep: 0.7
# Episode: 333, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1205, Memory: 14137, Loss_last_20_ep: 0.036, Reward_last_20_ep: 0.7
# Episode: 334, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.1201, Memory: 14161, Loss_last_20_ep: 0.0355, Reward_last_20_ep: 0.7
# Episode: 335, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1192, Memory: 14213, Loss_last_20_ep: 0.0351, Reward_last_20_ep: 0.7
# Episode: 336, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1182, Memory: 14267, Loss_last_20_ep: 0.0326, Reward_last_20_ep: 0.75
# Episode: 337, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1172, Memory: 14322, Loss_last_20_ep: 0.033, Reward_last_20_ep: 0.75
# Episode: 338, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.1155, Memory: 14423, Loss_last_20_ep: 0.0332, Reward_last_20_ep: 0.8
# Episode: 339, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.1145, Memory: 14479, Loss_last_20_ep: 0.0323, Reward_last_20_ep: 0.85
# Episode: 340, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1136, Memory: 14531, Loss_last_20_ep: 0.0318, Reward_last_20_ep: 0.85
# Episode: 341, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.1127, Memory: 14585, Loss_last_20_ep: 0.0301, Reward_last_20_ep: 0.85
# Episode: 342, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.111, Memory: 14686, Loss_last_20_ep: 0.0155, Reward_last_20_ep: 0.9
# Episode: 343, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.1101, Memory: 14741, Loss_last_20_ep: 0.0156, Reward_last_20_ep: 0.9
# Episode: 344, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.1097, Memory: 14763, Loss_last_20_ep: 0.0156, Reward_last_20_ep: 0.9
# Episode: 345, Episode_Steps: 51, Cum_Reward: 1.0,  Epsilon: 0.1089, Memory: 14815, Loss_last_20_ep: 0.0159, Reward_last_20_ep: 0.9
# ...
# Episode: 13987, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 264.4006, Reward_last_20_ep: 1.95
# Episode: 13988, Episode_Steps: 152, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 265.1031, Reward_last_20_ep: 2.1
# Episode: 13989, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 265.2623, Reward_last_20_ep: 2.1
# Episode: 13990, Episode_Steps: 221, Cum_Reward: 7.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 265.3184, Reward_last_20_ep: 2.05
# Episode: 13991, Episode_Steps: 203, Cum_Reward: 6.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 268.3783, Reward_last_20_ep: 2.2
# Episode: 13992, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 268.8257, Reward_last_20_ep: 2.15
# Episode: 13993, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 268.4358, Reward_last_20_ep: 2.15
# Episode: 13994, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 267.029, Reward_last_20_ep: 2.15
# Episode: 13995, Episode_Steps: 129, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 246.6819, Reward_last_20_ep: 2.2
# Episode: 13996, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 242.8784, Reward_last_20_ep: 2.35
# Episode: 13997, Episode_Steps: 158, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 243.1108, Reward_last_20_ep: 2.4
# Episode: 13998, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 222.119, Reward_last_20_ep: 2.3
# Episode: 13999, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 221.881, Reward_last_20_ep: 2.15
# Exporting episode: 14000 ...
# Episode: 14000, Episode_Steps: 176, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 221.5839, Reward_last_20_ep: 2.3
# Episode: 14001, Episode_Steps: 133, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 208.8822, Reward_last_20_ep: 2.45
# Episode: 14002, Episode_Steps: 106, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 185.5203, Reward_last_20_ep: 2.4
# Episode: 14003, Episode_Steps: 105, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 128.903, Reward_last_20_ep: 2.45
# Episode: 14004, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 109.4989, Reward_last_20_ep: 2.5
# Episode: 14005, Episode_Steps: 100, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 45.6461, Reward_last_20_ep: 2.6
# Episode: 14006, Episode_Steps: 84, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 35.7137, Reward_last_20_ep: 2.55
# Episode: 14007, Episode_Steps: 154, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 15.9269, Reward_last_20_ep: 2.7
# Episode: 14008, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 14.951, Reward_last_20_ep: 2.55
# Episode: 14009, Episode_Steps: 50, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 14.4753, Reward_last_20_ep: 2.55
# Episode: 14010, Episode_Steps: 176, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 14.5576, Reward_last_20_ep: 2.45
# Episode: 14011, Episode_Steps: 85, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 12.0284, Reward_last_20_ep: 2.25
# Episode: 14012, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.2021, Reward_last_20_ep: 2.25
# Episode: 14013, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.0362, Reward_last_20_ep: 2.2
# Episode: 14014, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.2472, Reward_last_20_ep: 2.2
# Episode: 14015, Episode_Steps: 133, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.7905, Reward_last_20_ep: 2.2
# Episode: 14016, Episode_Steps: 133, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.5463, Reward_last_20_ep: 2.15
# Episode: 14017, Episode_Steps: 133, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 9.9635, Reward_last_20_ep: 2.1
# Episode: 14018, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.5478, Reward_last_20_ep: 2.1
# Episode: 14019, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.4963, Reward_last_20_ep: 2.1
# Episode: 14020, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.2012, Reward_last_20_ep: 2.25
# Update target model
# Episode: 14021, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.3041, Reward_last_20_ep: 2.3
# Episode: 14022, Episode_Steps: 139, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.3652, Reward_last_20_ep: 2.35
# Episode: 14023, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.9826, Reward_last_20_ep: 2.3
# Episode: 14024, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.9439, Reward_last_20_ep: 2.3
# Episode: 14025, Episode_Steps: 152, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.9404, Reward_last_20_ep: 2.4
# Episode: 14026, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.9134, Reward_last_20_ep: 2.5
# Episode: 14027, Episode_Steps: 153, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.9977, Reward_last_20_ep: 2.5
# Episode: 14028, Episode_Steps: 105, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.9283, Reward_last_20_ep: 2.55
# Episode: 14029, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.8977, Reward_last_20_ep: 2.55
# Episode: 14030, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.4304, Reward_last_20_ep: 2.7
# Episode: 14031, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.7587, Reward_last_20_ep: 2.8
# Episode: 14032, Episode_Steps: 103, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.7584, Reward_last_20_ep: 2.85
# Episode: 14033, Episode_Steps: 107, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.689, Reward_last_20_ep: 2.95
# Episode: 14034, Episode_Steps: 108, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.5228, Reward_last_20_ep: 3.0
# Episode: 14035, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.3744, Reward_last_20_ep: 3.05
# Episode: 14036, Episode_Steps: 177, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.406, Reward_last_20_ep: 3.15
# Episode: 14037, Episode_Steps: 52, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2628, Reward_last_20_ep: 3.05
# Episode: 14038, Episode_Steps: 87, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2488, Reward_last_20_ep: 3.1
# Episode: 14039, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.9608, Reward_last_20_ep: 3.1
# Episode: 14040, Episode_Steps: 174, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.7947, Reward_last_20_ep: 2.95
# Episode: 14041, Episode_Steps: 137, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.5773, Reward_last_20_ep: 2.9
# Episode: 14042, Episode_Steps: 53, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.0814, Reward_last_20_ep: 2.8
# Episode: 14043, Episode_Steps: 50, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.4101, Reward_last_20_ep: 2.8
# Episode: 14044, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.4847, Reward_last_20_ep: 2.75
# Episode: 14045, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.9099, Reward_last_20_ep: 2.95
# Episode: 14046, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.9961, Reward_last_20_ep: 2.75
# Episode: 14047, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1394, Reward_last_20_ep: 2.8
# Episode: 14048, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.5715, Reward_last_20_ep: 2.75
# Episode: 14049, Episode_Steps: 196, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6221, Reward_last_20_ep: 2.9
# Episode: 14050, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6712, Reward_last_20_ep: 2.9
# Episode: 14051, Episode_Steps: 178, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6141, Reward_last_20_ep: 2.95
# Episode: 14052, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6276, Reward_last_20_ep: 2.9
# Episode: 14053, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6184, Reward_last_20_ep: 2.85
# Episode: 14054, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.492, Reward_last_20_ep: 2.8
# Episode: 14055, Episode_Steps: 324, Cum_Reward: 9.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.5832, Reward_last_20_ep: 3.05
# Episode: 14056, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.486, Reward_last_20_ep: 3.0
# Episode: 14057, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.4866, Reward_last_20_ep: 3.0
# Episode: 14058, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.023, Reward_last_20_ep: 2.95
# Episode: 14059, Episode_Steps: 45, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.8057, Reward_last_20_ep: 2.95
# Episode: 14060, Episode_Steps: 151, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.8036, Reward_last_20_ep: 2.9
# Episode: 14061, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.9189, Reward_last_20_ep: 2.95
# Episode: 14062, Episode_Steps: 103, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2837, Reward_last_20_ep: 3.0
# Episode: 14063, Episode_Steps: 157, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2953, Reward_last_20_ep: 3.15
# Episode: 14064, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2824, Reward_last_20_ep: 3.15
# Episode: 14065, Episode_Steps: 152, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.0536, Reward_last_20_ep: 2.95
# Episode: 14066, Episode_Steps: 84, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2993, Reward_last_20_ep: 3.05
# Episode: 14067, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.3586, Reward_last_20_ep: 2.9
# Episode: 14068, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1062, Reward_last_20_ep: 2.9
# Episode: 14069, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.0618, Reward_last_20_ep: 2.75
# Episode: 14070, Episode_Steps: 176, Cum_Reward: 5.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1962, Reward_last_20_ep: 2.6
# Episode: 14071, Episode_Steps: 203, Cum_Reward: 6.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1925, Reward_last_20_ep: 2.65
# Episode: 14072, Episode_Steps: 87, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1688, Reward_last_20_ep: 2.7
# Episode: 14073, Episode_Steps: 136, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.0623, Reward_last_20_ep: 2.8
# Episode: 14074, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1089, Reward_last_20_ep: 2.75
# Episode: 14075, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2157, Reward_last_20_ep: 2.7
# Episode: 14076, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.2138, Reward_last_20_ep: 2.7
# Episode: 14077, Episode_Steps: 54, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.3286, Reward_last_20_ep: 2.7
# Episode: 14078, Episode_Steps: 88, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 3.9292, Reward_last_20_ep: 2.75
# Episode: 14079, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.0317, Reward_last_20_ep: 2.75
# Episode: 14080, Episode_Steps: 221, Cum_Reward: 7.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.1309, Reward_last_20_ep: 2.9
# Episode: 14081, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 4.6982, Reward_last_20_ep: 2.9
# Episode: 14082, Episode_Steps: 87, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.4416, Reward_last_20_ep: 2.9
# Episode: 14083, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.4613, Reward_last_20_ep: 2.7
# Episode: 14084, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.4838, Reward_last_20_ep: 2.75
# Episode: 14085, Episode_Steps: 221, Cum_Reward: 7.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 6.0791, Reward_last_20_ep: 2.9
# Episode: 14086, Episode_Steps: 137, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.8833, Reward_last_20_ep: 2.95
# Episode: 14087, Episode_Steps: 158, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.9151, Reward_last_20_ep: 3.1
# Episode: 14088, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 5.8392, Reward_last_20_ep: 3.05
# Episode: 14089, Episode_Steps: 71, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 12.0272, Reward_last_20_ep: 3.05
# Episode: 14090, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.9419, Reward_last_20_ep: 3.2
# Episode: 14091, Episode_Steps: 200, Cum_Reward: 6.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.873, Reward_last_20_ep: 3.2
# Episode: 14092, Episode_Steps: 153, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 12.0371, Reward_last_20_ep: 3.25
# Episode: 14093, Episode_Steps: 79, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 12.1205, Reward_last_20_ep: 3.2
# Episode: 14094, Episode_Steps: 21, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 12.1022, Reward_last_20_ep: 3.2
# Episode: 14095, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.9342, Reward_last_20_ep: 3.2
# Episode: 14096, Episode_Steps: 153, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.9237, Reward_last_20_ep: 3.2
# Episode: 14097, Episode_Steps: 103, Cum_Reward: 2.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.9384, Reward_last_20_ep: 3.25
# Episode: 14098, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.8639, Reward_last_20_ep: 3.2
# Episode: 14099, Episode_Steps: 23, Cum_Reward: 0.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.774, Reward_last_20_ep: 3.15
# Episode: 14100, Episode_Steps: 272, Cum_Reward: 8.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 11.6994, Reward_last_20_ep: 3.2
# Episode: 14101, Episode_Steps: 203, Cum_Reward: 6.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.9817, Reward_last_20_ep: 3.3
# Episode: 14102, Episode_Steps: 175, Cum_Reward: 4.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.286, Reward_last_20_ep: 3.4
# Update target model
# Episode: 14103, Episode_Steps: 55, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.3407, Reward_last_20_ep: 3.45
# Episode: 14104, Episode_Steps: 44, Cum_Reward: 1.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.3536, Reward_last_20_ep: 3.45
# Episode: 14105, Episode_Steps: 324, Cum_Reward: 9.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.0223, Reward_last_20_ep: 3.55
# Episode: 14106, Episode_Steps: 145, Cum_Reward: 3.0,  Epsilon: 0.01, Memory: 53000, Loss_last_20_ep: 10.6376, Reward_last_20_ep: 3.55

# %%
first = True

if first:
    #state = env.reset()
    #state, reward, done, _ = env.step(1)
    for i in range(STATE_LENGTH):
        window_states.append(preprocessImage(state))
    first = False
    plt.imshow(state)

# %%
fig=plt.figure(figsize=(16, 16))
columns = 4
rows = 1
for i, img in enumerate(window_states):
    fig.add_subplot(rows, columns, i + 1)
    plt.imshow(img, cmap = 'gray')
plt.show()

# %%
# Actions: {0: No-op, 1:Fire(start game), 2: Right, 3: Left}
agent.act(np.asarray(window_states), ret_predictions = True)
# agent.act(np.asarray(window_states))

# %%
# Actions: {0: No-op, 1:Fire(start game), 2: Right, 3: Left}

window_states.append(preprocessImage(state))

fig=plt.figure(figsize=(16, 16))
columns = 4
rows = 1
for i, img in enumerate(window_states):
    fig.add_subplot(rows, columns, i + 1)
    plt.imshow(img, cmap = 'gray')
plt.show()

print(agent.model.predict(np.expand_dims(np.asarray(window_states).reshape(FRAME_WIDTH, FRAME_HEIGHT, STATE_LENGTH) , axis = 0)))
next_state, reward, done, _ = env.step(1)
print(reward, done)
plt.imshow(preprocessImage(next_state), cmap = 'gray')
state = next_state

# %%
# saveEpisode(path_input + episode_suffix, episode, frames)
# # create_gif(path_input + episode_suffix, path_output, episode, f'gif_episode_{episode}.gif', duration = GIF_DURATION)
# createVideo(path_input + episode_suffix, path_output, episode, f'video_episode_{episode}.avi', frames_window = FRAMES_WINDOW)
